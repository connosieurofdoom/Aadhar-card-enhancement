# %% [markdown]
# <a href="https://colab.research.google.com/github/connosieurofdoom/Aadhar-card-enhancement/blob/master/shareMareketDat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nsepy
# !pip install plotly
# !pip install wolframclient

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import math
import io
def plotter(fp,name):
    df = pd.read_csv(io.BytesIO(uploaded[fp]))
    col = list(df.columns)
    xcol = []
    for i in col:
        try:    
            if df.dtypes[i] == np.datetime64 or df.dtypes[i] == np.object:
                df[i] = df[i].apply(lambda date_str : np.datetime64(date_str)  ) # 
                xcol.append(i)
        except:
            try:
                if df.dtypes[i] == np.datetime64 or df.dtypes[i] == np.object:
                    df[i] = df[i].apply(lambda date_str :datetime.strptime(date_str, '%Y-%m-%d').date()) # np.datetime64(date_str)  )
                    xcol.append(i)
            except:
                pass



    ycol = set(col).difference(xcol)
    ycol = list(ycol)
    

    for i in ycol:
        if df.dtypes[i] == np.object:
            ycol.remove(i)

    #print(xcol,ycol)

    i = 1
    for j in xcol:
        for k in ycol:
            fig = plt.figure(i)
            fig.canvas.set_window_title(j+' vs '+k)
            plt.subplot(211)
            plt.grid(True)
            plt.plot(df[j],df[k])
            plt.xlabel(j)
            plt.ylabel(k)
            plt.title(j+' vs '+k)
            i+=1

    plt.show()



    #print(df.dtypes)
    #print(ycol)
    #print(xcol)


#plotter("SBIN.NS2.csv","SBIN")


def plotter2(fp,name):
    df = pd.read_csv(io.BytesIO(uploaded[fp]))
    col = list(df.columns)
    xcol = []
    for i in col:
        try:    
            if df.dtypes[i] == np.datetime64 or df.dtypes[i] == np.object:
                df[i] = df[i].apply(lambda date_str : np.datetime64(date_str)  ) # 
                xcol.append(i)
        except:
            try:
                if df.dtypes[i] == np.datetime64 or df.dtypes[i] == np.object:
                    df[i] = df[i].apply(lambda date_str :datetime.strptime(date_str, '%Y-%m-%d').date()) # np.datetime64(date_str)  )
                    xcol.append(i)
            except:
                pass



    ycol = set(col).difference(xcol)
    ycol = list(ycol)
    

    for i in ycol:
        if df.dtypes[i] == np.object:
            ycol.remove(i)

    #print(xcol,ycol)
    
    
    i = 1
    for j in xcol:
        for k in ycol:
            fig = px.line_3d(df, x = j, y = k )
            #fig = go.Figure()
            #fig.add_trace(go.Scatter(x = df[j], y = df[k], mode = 'lines', name = j+' vs '+k, color='variable'))

            fig.update_xaxes(rangeslider_visible=True)
            fig.show()
    

    """
    plt.show()"""
    #df_long=pd.melt(df, id_vars=xcol, value_vars=ycol)

    # plotly 
    #fig = px.line(df_long, x='Date', y='value', color='variable')
    #fig.update_xaxes(rangeslider_visible=True)
    #fig.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b8f45195-b48d-4326-8ca7-8442bd828586" name="files[]" multiple disabled />
#      <output id="result-b8f45195-b48d-4326-8ca7-8442bd828586">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving CIPLA.NS8.csv to CIPLA.NS8.csv

# %%
#from DatPlot import plotter
#plotter2(path,sy)
sy = str(input("Please input the symbol: "))
plotter2('CIPLA.NS8.csv',sy)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="35576845-9eb9-4921-9370-2175ab2b7807" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("35576845-9eb9-4921-9370-2175ab2b7807")) {
#                     Plotly.newPlot(
#                         '35576845-9eb9-4921-9370-2175ab2b7807',
# ...
